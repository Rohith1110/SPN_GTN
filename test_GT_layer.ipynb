# %% [markdown]
# # Install dependencies

# %%
# %pip install torch==2.0.1+cu118
# %pip install torchvision==0.15.2+cu118 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118
# %pip install torch-scatter torch-sparse torch-cluster torch-spline-conv -f https://data.pyg.org/whl/torch-2.0.1+cu118.html
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
# Note: you may need to restart the kernel to use updated packages.
# Looking in links: https://data.pyg.org/whl/torch-2.0.1+cu118.html
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# ! pip install torch-geometric==1.7.2
! pip install torch-geometric==2.6.1
# Out:
# ...
#   Using cached torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
# ...
# Using cached torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
# ...
#   Attempting uninstall: torch-geometric
#     Found existing installation: torch_geometric 1.7.2
#     Uninstalling torch_geometric-1.7.2:
#       Successfully uninstalled torch_geometric-1.7.2
# ...

# %%
import torch_geometric
from torch_scatter import scatter_mean
print("All PyTorch Geometric components imported successfully!")
import torch
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    torch.cuda.set_device(device)
else:
    device = torch.device("cpu")
print("Device:", device)
print("CUDA available:", torch.cuda.is_available())
print("Number of GPUs:", torch.cuda.device_count())
# print("Current device:", torch.cuda.current_device())
print("Device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected")
# Out:
# All PyTorch Geometric components imported successfully!
# Device: cuda:0
# CUDA available: True
# Number of GPUs: 1
# Device name: NVIDIA GeForce RTX 3090

# %% [markdown]
# # Test GT layer with GCNv2 Joint Model on PubMed dataset

# %%
# !python solve_proxy.py --dataset pubmed --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 8 --transformer_dropout_prob 0.05 --transformer_layer_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='pubmed', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[8], transformer_dropout_prob=0.05, transformer_layer_norm=True, transformer_batch_norm=False, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=False, 
# ...

# %%
# !python solve_proxy.py --dataset pubmed --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 8 --transformer_dropout_prob 0.05 --joint-model GCN2
# Out:
# Namespace(dataset='pubmed', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[8], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False
# ...

# %% [markdown]
# # Test GCNv2 Joint Model on PubMed dataset

# %%
# !python solve_proxy.py --dataset pubmed --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GCN2
# Out:
# Namespace(dataset='pubmed', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False, 
# ...

# %% [markdown]
# ## Test GT layer with GCN Joint Model on Cora dataset with GT layer and Laplacian PE

# %%
# !python solve_proxy.py --dataset cora --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 2 --transformer_dropout_prob 0.05 --use-laplacian-pe --pe-dim 32 --joint-model GCN --GNN-hidden-sizes 256 256
# Out:
# Namespace(dataset='cora', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[2], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=True, pe
# ...

# %% [markdown]
# ## Test GT layer with GATv2 Joint Model on Citeseer dataset

# %%
# !python solve_proxy.py --dataset citeseer --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 4 --joint-model GATv2 --GNN-hidden-sizes 256 256 --GATv2-heads 4 4 6
# Out:
# Namespace(dataset='citeseer', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[4], transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, max_prod_bp_steps=5, s
# ...

# %% [markdown]
# ## Test GT layer with GATv2 Joint Model on Dblp dataset

# %%
# !python solve_proxy.py --dataset dblp --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 4 --joint-model GATv2 --GNN-hidden-sizes 256 256 --GATv2-heads 4 4 6
# Out:
# Namespace(dataset='dblp', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[4], transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, max_prod_bp_steps=5, sum_p
# ...

# %% [markdown]
# # Test with GCNv2 Joint Model on Cora dataset with GT Layer

# %%
# !python solve_proxy.py --dataset cora --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 4 --transformer_dropout_prob 0.05 --transformer_layer_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='cora', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[4], transformer_dropout_prob=0.05, transformer_layer_norm=True, transformer_batch_norm=False, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=False, pe
# ...

# %% [markdown]
# # Test GCNv2 Joint Model on Cora dataset

# %%
# !python solve_proxy.py --dataset cora --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GCN2
# Out:
# Namespace(dataset='cora', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False, pe
# ...

# %% [markdown]
# # Test GCN2 Joint Model on Citeseer dataset with GT Layer

# %%
# !python solve_proxy.py --dataset citeseer --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 8 --transformer_layer_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='citeseer', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[8], transformer_dropout_prob=0.0, transformer_layer_norm=True, transformer_batch_norm=False, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=False,
# ...

# %% [markdown]
# # Test GCN2 Joint Model on Citeseer dataset

# %%
# !python solve_proxy.py --dataset citeseer --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GCN2
# Out:
# Namespace(dataset='citeseer', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False
# ...

# %% [markdown]
# # Test GCN2 Joint Model on DBLP dataset with GT layer

# %%
# !python solve_proxy.py --dataset dblp --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 8 --transformer_batch_norm --transformer_residual --use-laplacian-pe --pe-dim 4 --joint-model GCN2
# Out:
# Namespace(dataset='dblp', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[8], transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=True, pe_d
# ...

# %% [markdown]
# # Test GCN2 Joint Model on DBLP dataset

# %%
# !python solve_proxy.py --dataset dblp --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GAT
# Out:
# Namespace(dataset='dblp', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False, pe_
# ...

# %%
# !python solve_proxy.py --dataset dblp --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GATv2 --GNN-hidden-sizes 1024 1024 --GATv2-heads 4 4 6
# Out:
# Namespace(dataset='dblp', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False, pe_
# ...

# %%
# !python solve_proxy.py --dataset dblp --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GCN2
# Out:
# Namespace(dataset='dblp', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False, pe
# ...

# %% [markdown]
# # Test with GCN2 Joint Model on PPI-10-0 dataset with GT layer with different configurations

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 2 --transformer_dropout_prob 0.1 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[2], transformer_dropout_prob=0.1, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=Fals
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 2 --transformer_dropout_prob 0.1 --transformer_layer_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[2], transformer_dropout_prob=0.1, transformer_layer_norm=True, transformer_batch_norm=False, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=False,
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 2 --transformer_dropout_prob 0.1 --use-laplacian-pe --pe-dim 32 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[2], transformer_dropout_prob=0.1, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=True
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 2 --transformer_dropout_prob 0.05 --transformer_layer_norm --transformer_residual --use-laplacian-pe --pe-dim 16 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[2], transformer_dropout_prob=0.05, transformer_layer_norm=True, transformer_batch_norm=False, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=True,
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 4 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --use-laplacian-pe --pe-dim 16 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[4], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=True,
# ...

# %% [markdown]
# ## GCN2 + GT Layer 64 heads 1 layer dropout 0.05 + Batch Norm is best so far

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 16 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --use-laplacian-pe --pe-dim 4 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[16], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=True
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 16 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --use-laplacian-pe --pe-dim 2 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[16], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=True
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 16 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[16], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=Fals
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 32 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[32], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=Fals
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 64 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[64], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=Fals
# ...

# %%
# !python solve_proxy.py --dataset ppi-2-10 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-2-10', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False
# ...

# %%
# !python solve_proxy.py --dataset ppi-2-10 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 16 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='ppi-2-10', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[16], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=Fals
# ...

# %%
# !python solve_proxy.py --dataset ppi-2-10 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 32 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='ppi-2-10', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[32], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=Fals
# ...

# %%
# !python solve_proxy.py --dataset ppi-2-10 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 64 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --use-laplacian-pe --pe-dim 2 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-2-10', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[64], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=True
# ...

# %%
# !python solve_proxy.py --dataset ppi-2-10 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 32 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --use-laplacian-pe --pe-dim 1 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-2-10', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[32], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=True
# ...

# %% [markdown]
# ## PPI-1-23 with and without GT Layer

# %%
# !python solve_proxy.py --dataset ppi-1-23 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 64 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='ppi-1-23', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[64], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=Fals
# ...

# %%
# !python solve_proxy.py --dataset ppi-1-23 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 64 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --use-laplacian-pe --pe-dim 2 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-1-23', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[64], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=True
# ...

# %%
# !python solve_proxy.py --dataset ppi-1-23 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-1-23', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False
# ...

# %%
# !python solve_proxy.py --dataset ppi-1-23 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model SAGE
# Out:
# Namespace(dataset='ppi-1-23', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False,
# ...

# %% [markdown]
# ## PPI-1-69 with and without GT Layer

# %%
# !python solve_proxy.py --dataset ppi-1-69 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 64 --transformer_dropout_prob 0.05 --transformer_batch_norm --transformer_residual --joint-model GCN2
# Out:
# Namespace(dataset='ppi-1-69', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[64], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=True, transformer_residual=True, transformer_use_bias=False, use_laplacian_pe=Fals
# ...

# %%
# !python solve_proxy.py --dataset ppi-1-69 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GCN2
# Out:
# Namespace(dataset='ppi-1-69', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='layer', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False
# ...

# %%
# !python solve_proxy.py --dataset ppi-1-69 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model SAGE --GNN-hidden-sizes 64 64
# Out:
# Namespace(dataset='ppi-1-69', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False,
# ...

# %%
# !python solve_proxy.py --dataset ppi-1-69 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --joint-model GATv2 --GNN-hidden-sizes 256 256 --GATv2-heads 4 4 6
# Out:
# Namespace(dataset='ppi-1-69', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=False, num_transformer_layers=1, transformer_out_dim=128, transformer_num_heads=8, transformer_dropout_prob=0.0, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False,
# ...

# %% [markdown]
# # Test with GCN Joint Model on PPI-10-0 dataset with GT layer and Laplacian PE

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 2 --transformer_dropout_prob 0.05 --use-laplacian-pe --pe-dim 32 --joint-model GCN --GNN-hidden-sizes 256 256
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[2], transformer_dropout_prob=0.05, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=True
# ...

# %%
# !python solve_proxy.py --dataset ppi-10-0 --solve-proxy-epochs 1000 --solve-proxy-eval-every 50 --use_gt_layer --num_transformer_layers 1 --transformer_out_dim 256 --transformer_num_heads 2 --transformer_dropout_prob 0.3 --joint-model GCN --GNN-hidden-sizes 256 256
# Out:
# Namespace(dataset='ppi-10-0', seed=1, no_proxy=False, solve_proxy_epochs=1000, solve_proxy_node_lr=0.005, solve_proxy_edge_lr=0.001, solve_proxy_eval_every=50, separate_model_after_proxy=False, refine_epochs=300, refine_node_lr=1e-05, refine_edge_lr=1e-05, refine_eval_every=5, ckpt_dir='./results', load_ckpt='', log_str='', proxy_log_file='proxy_log.csv', pm_result_file='pm_result.csv', pp_result_file='pp_result.csv', refine_log_file='refine_log.csv', rm_result_file='refine_result.csv', joint_model=True, no_log_softmax=False, split_repr=False, MLP_activation='ReLU', MLP_norm_module='none', edge_repr_dropout=0.5, edge_label_predictor='concat', edge_hidden_sizes=(64,), dropout_prob=0, GNN_norm_module='none', ckpt_grad=False, use_gt_layer=True, num_transformer_layers=1, transformer_out_dim=256, transformer_num_heads=[2], transformer_dropout_prob=0.3, transformer_layer_norm=False, transformer_batch_norm=False, transformer_residual=False, transformer_use_bias=False, use_laplacian_pe=False
# ...
